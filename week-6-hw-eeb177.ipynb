# %% [markdown]
# # Part 1: Code Academy Review

# %% [markdown]
# ![badge1](/home/eeb177-student/Desktop/eeb-177/homework/python_syntax.png)

# %% [markdown]
# ![badge2](/home/eeb177-student/Desktop/eeb-177/homework/string_and_console.png)

# %% [markdown]
# ![badge3](/home/eeb177-student/Desktop/eeb-177/homework/conditionals_control.png)

# %% [markdown]
# ![badge4](/home/eeb177-student/Desktop/eeb-177/homework/functions.png)

# %% [markdown]
# ![badge5](/home/eeb177-student/Desktop/eeb-177/homework/python_lists_and_dictionaries.png)

# %% [markdown]
# ![badge6](/home/eeb177-student/Desktop/eeb-177/homework/lists_and_functions.png)

# %% [markdown]
# ![badge7](/home/eeb177-student/Desktop/eeb-177/homework/loops.png)

# %% [markdown]
# ![badge8](/home/eeb177-student/Desktop/eeb-177/homework/practice_makes_perfect.png)

# %%
#for some reason, the format learned in class is not working as seen above
#trying a different method

# %%
from IPython.display import Image
Image(filename = '/home/eeb177-student/Desktop/eeb-177/homework/python_syntax.png')

# %%
from IPython.display import Image
Image(filename = '/home/eeb177-student/Desktop/eeb-177/homework/string_and_console.png')

# %%
from IPython.display import Image
Image(filename = '/home/eeb177-student/Desktop/eeb-177/homework/conditionals_control.png')
# forgot to screenshot immediately after finishing module so had to go to badge history to screenshot record

# %%
from IPython.display import Image
Image(filename = '/home/eeb177-student/Desktop/eeb-177/homework/functions.png')

# %%
from IPython.display import Image
Image(filename = '/home/eeb177-student/Desktop/eeb-177/homework/python_lists_and_dictionaries.png')
# forgot to screenshot immediately after finishing module so had to go to badge history to screenshot record

# %%
from IPython.display import Image
Image(filename = '/home/eeb177-student/Desktop/eeb-177/homework/lists_and_functions.png')

# %%
from IPython.display import Image
Image(filename = '/home/eeb177-student/Desktop/eeb-177/homework/loops.png')

# %%
from IPython.display import Image
Image(filename = '/home/eeb177-student/Desktop/eeb-177/homework/practice_makes_perfect.png')
# forgot to screenshot immediately after finishing module so had to go to badge history to screenshot record
